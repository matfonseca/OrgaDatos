# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
cd Algorithms
# Out:
# /home/olix/Documentos/datos/tp2master/OrgaDatos/TP2/Algorithms

# %%
postulations = pd.read_csv('postulantes3M.csv')

# %%
postulations.head()
# Out:
#       idaviso idpostulante  cantVistas         nombre    estado  nombre_sort  \
# 0  1112436970      EzeYVlb         1.0  Universitario  En Curso          3.0
# 1  1112312616      8MZmY0W         1.0  Universitario  En Curso          3.0
# 2  1112237518      MVrZ04K         1.0     Secundario  Graduado          1.0
# 3  1112459934      qev12B1         1.0  Universitario  Graduado          3.0
# 4  1112393989      8MPQvvL         1.0  Universitario  En Curso          3.0
#
#   fechanacimiento  sexo     fechapostulacion  idpais  \
# 0      1998-02-22  MASC  2018-04-03 05:00:11       1
# 1      1992-03-25   FEM  2018-02-05 19:29:22       1
# 2      1998-06-03   FEM  2018-01-21 20:14:01       1
# 3      1990-05-25   FEM  2018-04-16 09:17:23       1
# 4      1998-02-06   FEM  2018-03-13 10:50:26       1
#
#                                               titulo  \
# 0   Representante de Atención al cliente - Part Time
# 1                                Vendedor en Rosario
# 2  Importante Empresa busca incorporar un emplead...
# 3       Recepcionista - Concesionario Oficial Toyota
# 4  OPERADORES TELEFÓNICOS  TELEMARKETERS SIN EXP...
#
#                                          descripcion        nombre_zona  \
# 0  <p style=""><strong><span style="">Adecco Offi...  Gran Buenos Aires
# 1  <p>En <strong>Garbarino</strong> nos encontram...  Gran Buenos Aires
# 2  <p><span>Sera requisito contar con experiencia...  Gran Buenos Aires
# 3  <p> </p><p><span style="">Nuestro Cliente, Imp...  Gran Buenos Aires
# 4  <p>¿Estás en búsqueda trabajo pero no tenes ex...  Gran Buenos Aires
#
#   tipo_de_trabajo         nivel_laboral               nombre_area
# 0       Part-time                Junior       Atención al Cliente
# 1       Full-time                Junior                    Ventas
# 2       Full-time                  Otro  Mantenimiento y Limpieza
# 3       Full-time  Senior / Semi-Senior             Recepcionista
# 4   Primer empleo                  Otro                    Ventas

# %%
postulations.drop(columns=['idpais','fechapostulacion'],inplace = True)

# %%
postulations['se_postulo'] = 1

# %%
postulations.drop(columns = ['nombre'],inplace = True)

# %%
postulations.head()
# Out:
#       idaviso idpostulante  cantVistas    estado  nombre_sort fechanacimiento  \
# 0  1112436970      EzeYVlb         1.0  En Curso          3.0      1998-02-22
# 1  1112312616      8MZmY0W         1.0  En Curso          3.0      1992-03-25
# 2  1112237518      MVrZ04K         1.0  Graduado          1.0      1998-06-03
# 3  1112459934      qev12B1         1.0  Graduado          3.0      1990-05-25
# 4  1112393989      8MPQvvL         1.0  En Curso          3.0      1998-02-06
#
#    sexo                                             titulo  \
# 0  MASC   Representante de Atención al cliente - Part Time
# 1   FEM                                Vendedor en Rosario
# 2   FEM  Importante Empresa busca incorporar un emplead...
# 3   FEM       Recepcionista - Concesionario Oficial Toyota
# 4   FEM  OPERADORES TELEFÓNICOS  TELEMARKETERS SIN EXP...
#
#                                          descripcion        nombre_zona  \
# 0  <p style=""><strong><span style="">Adecco Offi...  Gran Buenos Aires
# 1  <p>En <strong>Garbarino</strong> nos encontram...  Gran Buenos Aires
# 2  <p><span>Sera requisito contar con experiencia...  Gran Buenos Aires
# 3  <p> </p><p><span style="">Nuestro Cliente, Imp...  Gran Buenos Aires
# 4  <p>¿Estás en búsqueda trabajo pero no tenes ex...  Gran Buenos Aires
#
#   tipo_de_trabajo         nivel_laboral               nombre_area  se_postulo
# 0       Part-time                Junior       Atención al Cliente           1
# 1       Full-time                Junior                    Ventas           1
# 2       Full-time                  Otro  Mantenimiento y Limpieza           1
# 3       Full-time  Senior / Semi-Senior             Recepcionista           1
# 4   Primer empleo                  Otro                    Ventas           1

# %%
notpostulations = pd.read_csv('no_postulantes3M.csv')

# %%
notpostulations.head()
# Out:
#       idaviso idpostulante  cantVistas      estado  nombre_sort  \
# 0  1000641565      RzrpMqR         3.0    En Curso          3.0
# 1  1002377536       1Y2o2Q         1.0    En Curso          0.0
# 2  1002461239       aM4lPZ         1.0    En Curso          3.0
# 3  1002490173       Y1r8Bq         1.0    Graduado          1.0
# 4  1110478929      EzeY514         1.0  Abandonado          3.0
#
#   fechanacimiento  sexo                                             titulo  \
# 0      1995-12-15   FEM                                 VENDEDOR FULL TIME
# 1      1987-09-18  MASC  Personal con experiencia en lavandería  para H...
# 2      1992-01-26   FEM             Analista de Administración de Personal
# 3      1990-12-01  MASC                        Administrativa/o Comercial
# 4      1981-02-24  MASC                  Vendedor Viajante CÓRDOBA CAPITAL
#
#                                          descripcion        nombre_zona  \
# 0  <p> <strong>Importante empresa ubicada en la z...    Capital Federal
# 1  <p><strong><span lang="ES">Adecco Hoteles y Ca...  Gran Buenos Aires
# 2  <p style=""><span style="">Sanatorio ITOIZ se ...  Gran Buenos Aires
# 3  <p>Somos una empresa que elabora y distribuye ...  Gran Buenos Aires
# 4  <p>Somos una empresa multinacional que opera e...  Gran Buenos Aires
#
#   tipo_de_trabajo         nivel_laboral                 nombre_area  \
# 0       Full-time  Senior / Semi-Senior                      Ventas
# 1       Full-time  Senior / Semi-Senior               Mantenimiento
# 2       Full-time  Senior / Semi-Senior  Administración de Personal
# 3       Full-time  Senior / Semi-Senior              Administración
# 4       Full-time  Senior / Semi-Senior                      Ventas
#
#    se_postulo
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0

# %%
#Concateno las postulaciones con las NO postulaciones

frames = [postulations,notpostulations]
total = pd.concat(frames, ignore_index = True)

# %%
total.drop_duplicates(subset=['idpostulante','idaviso'], keep = 'first',inplace = True)
total.reset_index(inplace = True,drop = True)

# %%
total.count()
# Out:
# idaviso            5957812
# idpostulante       5957812
# cantVistas         5957812
# estado             5557503
# nombre_sort        5557503
# fechanacimiento    5766358
# sexo               5957812
# titulo             5957812
# descripcion        5957812
# nombre_zona        5957812
# tipo_de_trabajo    5957812
# nivel_laboral      5957812
# nombre_area        5957812
# se_postulo         5957812
# dtype: int64

# %%
total.to_csv("data6M.csv", index = False)
