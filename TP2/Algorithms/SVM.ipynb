# %% [markdown]
# # SVM

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas.util import hash_pandas_object
from sklearn.ensemble import AdaBoostClassifier

# %matplotlib inline

# %%
postulations = pd.read_csv('../DataAnalysis/postulaciones_nopostulaciones.csv')

# %%
postulations.head()
# Out:
#    Unnamed: 0 idpostulante     idaviso     nombre    estado fechanacimiento  \
# 0           0      4rP6q15  1112145679  Doctorado  En Curso             NaN
# 1           1      RzMvGDo  1112145679  Doctorado  Graduado      1986-08-21
# 2           2      owav2La  1112145679  Doctorado  En Curso      1998-03-14
# 3           3       1eWdwB  1112145679  Doctorado  Graduado      1981-12-31
# 4           4      2zQMWYa  1112145679  Doctorado  Graduado      1989-05-05
#
#          sexo  idpais                           titulo        nombre_zona  \
# 0  NO_DECLARA       1  Telecobrador - Importante Banco  Gran Buenos Aires
# 1        MASC       1  Telecobrador - Importante Banco  Gran Buenos Aires
# 2         FEM       1  Telecobrador - Importante Banco  Gran Buenos Aires
# 3         FEM       1  Telecobrador - Importante Banco  Gran Buenos Aires
# 4         FEM       1  Telecobrador - Importante Banco  Gran Buenos Aires
#
#   tipo_de_trabajo         nivel_laboral  nombre_area  se_postulo
# 0       Full-time  Senior / Semi-Senior  Call Center           1
# 1       Full-time  Senior / Semi-Senior  Call Center           1
# 2       Full-time  Senior / Semi-Senior  Call Center           1
# 3       Full-time  Senior / Semi-Senior  Call Center           1
# 4       Full-time  Senior / Semi-Senior  Call Center           1

# %%
from sklearn.base import TransformerMixin

class DataFrameImputer(TransformerMixin):

    def __init__(self):
        """Impute missing values.

        Columns of dtype object are imputed with the most frequent value 
        in column.

        Columns of other types are imputed with mean of column.

        """
    def fit(self, X, y=None):

        self.fill = pd.Series([X[c].value_counts().index[0]
            if X[c].dtype == np.dtype('O') else X[c].mean() for c in X],
            index=X.columns)

        return self

    def transform(self, X, y=None):
        return X.fillna(self.fill)

# %%
data = DataFrameImputer().fit_transform(postulations)

# %%
data.head()
# Out:
#    Unnamed: 0 idpostulante     idaviso     nombre    estado fechanacimiento  \
# 0           0      4rP6q15  1112145679  Doctorado  En Curso      1993-12-09
# 1           1      RzMvGDo  1112145679  Doctorado  Graduado      1986-08-21
# 2           2      owav2La  1112145679  Doctorado  En Curso      1998-03-14
# 3           3       1eWdwB  1112145679  Doctorado  Graduado      1981-12-31
# 4           4      2zQMWYa  1112145679  Doctorado  Graduado      1989-05-05
#
#          sexo  idpais                           titulo        nombre_zona  \
# 0  NO_DECLARA       1  Telecobrador - Importante Banco  Gran Buenos Aires
# 1        MASC       1  Telecobrador - Importante Banco  Gran Buenos Aires
# 2         FEM       1  Telecobrador - Importante Banco  Gran Buenos Aires
# 3         FEM       1  Telecobrador - Importante Banco  Gran Buenos Aires
# 4         FEM       1  Telecobrador - Importante Banco  Gran Buenos Aires
#
#   tipo_de_trabajo         nivel_laboral  nombre_area  se_postulo
# 0       Full-time  Senior / Semi-Senior  Call Center           1
# 1       Full-time  Senior / Semi-Senior  Call Center           1
# 2       Full-time  Senior / Semi-Senior  Call Center           1
# 3       Full-time  Senior / Semi-Senior  Call Center           1
# 4       Full-time  Senior / Semi-Senior  Call Center           1

# %%
clf = svm.SVC()
clf.fit(postulations.iloc[:,3:12], postulations.iloc[:,13])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-a4114c0ee68e> in <module>()
#       1 clf = svm.SVC()
# ----> 2 clf.fit(postulations.iloc[:,3:12], postulations.iloc[:,13])
#
# /usr/local/lib/python3.5/dist-packages/sklearn/svm/base.py in fit(self, X, y, sample_weight)
#     147         self._sparse = sparse and not callable(self.kernel)
#     148
# --> 149         X, y = check_X_y(X, y, dtype=np.float64, order='C', accept_sparse='csr')
#     150         y = self._validate_targets(y)
#     151
#
# /usr/local/lib/python3.5/dist-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     571     X = check_array(X, accept_sparse, dtype, order, copy, force_all_finite,
#     572                     ensure_2d, allow_nd, ensure_min_samples,
# --> 573                     ensure_min_features, warn_on_dtype, estimator)
#     574     if multi_output:
#     575         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# /usr/local/lib/python3.5/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     431                                       force_all_finite)
#     432     else:
# --> 433         array = np.array(array, dtype=dtype, order=order, copy=copy)
#     434
#     435         if ensure_2d:
#
# ValueError: could not convert string to float: 'Senior / Semi-Senior'
