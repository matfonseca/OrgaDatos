# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
cd Algorithms
# Out:
# /home/olix/Documentos/datos/tp2master/OrgaDatos/TP2/Algorithms

# %%
postulations = pd.read_csv('postulantes2M.csv')

# %%
postulations.head()
# Out:
#   idpostulante         nombre      estado  nombre_sort fechanacimiento  sexo  \
# 0      EzpVOLz  Universitario    En Curso          3.0      1987-03-16  MASC
# 1      kPjordV  Universitario    En Curso          3.0      1998-11-19  MASC
# 2      pzNk9Rr     Secundario    Graduado          1.0      1983-05-27  MASC
# 3      vV3BMz1     Secundario    Graduado          1.0      1954-03-14  MASC
# 4       a4GRrN  Universitario  Abandonado          3.0      1978-11-23  MASC
#
#       idaviso     fechapostulacion  idpais  \
# 0  1111662226  2018-02-21 07:28:55       1
# 1  1111413600  2018-04-04 16:12:46       1
# 2  1112401116  2018-03-20 06:16:42       1
# 3  1112319004  2018-04-13 20:14:29       1
# 4  1112094756  2018-04-12 13:29:44       1
#
#                                               titulo  \
# 0                    Cajeros/as- Atencion al cliente
# 1  Operador telefónico /  Retención y Fidelizació...
# 2                 Técnico en Reparación de Celulares
# 3                       Asesores Comerciales NEUQUEN
# 4        Representante de Atencion al Cliente/ Banco
#
#                                          descripcion        nombre_zona  \
# 0  <p>En Farmacia Central Oeste estamos buscando ...  Gran Buenos Aires
# 1  <p>Gestión de seguimiento de reclamos, retenci...    Capital Federal
# 2  <p style=""><span style="">Nuestro Cliente una...  Gran Buenos Aires
# 3  <p style="">En <strong style="">PROSEGUR ACTIV...    Capital Federal
# 4  <p>Seleccionaremos para Importante Entidad Ban...  Gran Buenos Aires
#
#   tipo_de_trabajo         nivel_laboral      nombre_area
# 0       Full-time                  Otro     Farmacéutica
# 1       Part-time                  Otro    Telemarketing
# 2       Full-time                Junior  Soporte Técnico
# 3       Full-time                Junior           Ventas
# 4       Part-time  Senior / Semi-Senior      Call Center

# %%
postulations.drop(columns=['idpais','fechapostulacion'],inplace = True)

# %%
postulations['se_postulo'] = 1

# %%
postulations.drop(columns = ['nombre'],inplace = True)

# %%
postulations.head()
# Out:
#   idpostulante      estado  nombre_sort fechanacimiento  sexo     idaviso  \
# 0      EzpVOLz    En Curso          3.0      1987-03-16  MASC  1111662226
# 1      kPjordV    En Curso          3.0      1998-11-19  MASC  1111413600
# 2      pzNk9Rr    Graduado          1.0      1983-05-27  MASC  1112401116
# 3      vV3BMz1    Graduado          1.0      1954-03-14  MASC  1112319004
# 4       a4GRrN  Abandonado          3.0      1978-11-23  MASC  1112094756
#
#                                               titulo  \
# 0                    Cajeros/as- Atencion al cliente
# 1  Operador telefónico /  Retención y Fidelizació...
# 2                 Técnico en Reparación de Celulares
# 3                       Asesores Comerciales NEUQUEN
# 4        Representante de Atencion al Cliente/ Banco
#
#                                          descripcion        nombre_zona  \
# 0  <p>En Farmacia Central Oeste estamos buscando ...  Gran Buenos Aires
# 1  <p>Gestión de seguimiento de reclamos, retenci...    Capital Federal
# 2  <p style=""><span style="">Nuestro Cliente una...  Gran Buenos Aires
# 3  <p style="">En <strong style="">PROSEGUR ACTIV...    Capital Federal
# 4  <p>Seleccionaremos para Importante Entidad Ban...  Gran Buenos Aires
#
#   tipo_de_trabajo         nivel_laboral      nombre_area  se_postulo
# 0       Full-time                  Otro     Farmacéutica           1
# 1       Part-time                  Otro    Telemarketing           1
# 2       Full-time                Junior  Soporte Técnico           1
# 3       Full-time                Junior           Ventas           1
# 4       Part-time  Senior / Semi-Senior      Call Center           1

# %%
notpostulations = pd.read_csv('no_postulantes2M.csv')

# %%
notpostulations.head()
# Out:
#       idaviso idpostulante    estado  nombre_sort fechanacimiento  sexo  \
# 0  1112427544      8MLO1DO  Graduado          3.0      1992-12-08   FEM
# 1  1112427544      PmLx3ZZ  En Curso          3.0      1988-12-20  MASC
# 2  1112427544      ekOJrk9  Graduado          1.0      1995-07-02   FEM
# 3  1112427544      wVjOpVV       NaN          NaN      1992-11-08   FEM
# 4  1112427544       N9q1x4  En Curso          3.0      1989-11-06   FEM
#
#                                               titulo  \
# 0  Auditor de Campo - Capital Federal (Encuestas ...
# 1  Auditor de Campo - Capital Federal (Encuestas ...
# 2  Auditor de Campo - Capital Federal (Encuestas ...
# 3  Auditor de Campo - Capital Federal (Encuestas ...
# 4  Auditor de Campo - Capital Federal (Encuestas ...
#
#                                          descripcion        nombre_zona  \
# 0  <p>Nielsen, empresa multinacional busca:</p><p...  Gran Buenos Aires
# 1  <p>Nielsen, empresa multinacional busca:</p><p...  Gran Buenos Aires
# 2  <p>Nielsen, empresa multinacional busca:</p><p...  Gran Buenos Aires
# 3  <p>Nielsen, empresa multinacional busca:</p><p...  Gran Buenos Aires
# 4  <p>Nielsen, empresa multinacional busca:</p><p...  Gran Buenos Aires
#
#   tipo_de_trabajo nivel_laboral nombre_area  se_postulo
# 0       Full-time        Junior    Producto           0
# 1       Full-time        Junior    Producto           0
# 2       Full-time        Junior    Producto           0
# 3       Full-time        Junior    Producto           0
# 4       Full-time        Junior    Producto           0

# %%
#Concateno las postulaciones con las NO postulaciones

frames = [postulations,notpostulations]
total = pd.concat(frames, ignore_index = True)

# %%
total.drop_duplicates(subset=['idpostulante','idaviso'], keep = 'first',inplace = True)
total.reset_index(inplace = True,drop = True)

# %%
total.count()
# Out:
# descripcion        3981100
# estado             3892067
# fechanacimiento    3907153
# idaviso            3981100
# idpostulante       3981100
# nivel_laboral      3981100
# nombre_area        3981100
# nombre_sort        3892067
# nombre_zona        3981100
# se_postulo         3981100
# sexo               3981100
# tipo_de_trabajo    3981100
# titulo             3981100
# dtype: int64

# %%
total.to_csv("data4M.csv", index = False)
